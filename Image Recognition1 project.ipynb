# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
gv=os.listdir("C:/Users/Ganesh Madhav/Desktop/Image Processing/Gv P")
ani=os.listdir("C:/Users/Ganesh Madhav/Desktop/Image Processing/Anirudh")
u1=os.listdir("C:/Users/Ganesh Madhav/Desktop/Image Processing/Yuvan")

# %%
limit=10
gv_images=[None]*limit
j=0
for i in gv:
    if(j<limit):
        gv_images[j]=imread("C:/Users/Ganesh Madhav/Desktop/Image Processing/Gv P/"+i)
        j+=1
    else:
         break

# %%
limit=10
ani_images=[None]*limit
j=0
for i in ani:
    if(j<limit):
        ani_images[j]=imread("C:/Users/Ganesh Madhav/Desktop/Image Processing/Anirudh/"+i)
        j+=1
    else:
         break

# %%
limit=10
u1_images=[None]*limit
j=0
for i in u1:
    if(j<limit):
        u1_images[j]=imread("C:/Users/Ganesh Madhav/Desktop/Image Processing/Yuvan/"+i)
        j+=1
    else:
         break

# %%
imshow(gv_images[0])

# %%
imshow(ani_images[0])

# %%
imshow(u1_images[0])

# %%
gv_images[9].shape
# Out:
# (200, 252, 3)

# %%
ani_images[8].shape
# Out:
# (168, 299, 3)

# %%
u1_images[9].shape
# Out:
# (168, 299, 3)

# %%
gv_gray=[None]*limit
j=0
for i in gv:
    if(j<limit):
        gv_gray[j]=rgb2gray(gv_images[j])
        j+=1
    else:
        break

# %%
ani_gray=[None]*limit
j=0
for i in ani:
    if(j<limit):
        ani_gray[j]=rgb2gray(ani_images[j])
        j+=1
    else:
        break

# %%
u1_gray=[None]*limit
j=0
for i in u1:
    if(j<limit):
        u1_gray[j]=rgb2gray(u1_images[j])
        j+=1
    else:
        break

# %%
imshow(gv_gray[0])

# %%
imshow(ani_gray[0])

# %%
imshow(u1_gray[0])

# %%
gv_gray[0].shape
# Out:
# (225, 225)

# %%
ani_gray[0].shape
# Out:
# (175, 288)

# %%
u1_gray[0].shape
# Out:
# (275, 183)

# %%
for j in range (10):
    gv=gv_gray[j]
    gv_gray[j]=resize(gv,(512,512))

# %%
for j in range (10):
    ani=ani_gray[j]
    ani_gray[j]=resize(ani,(512,512))

# %%
for j in range (10):
    u1=u1_gray[j]
    u1_gray[j]=resize(u1,(512,512))

# %%
gv_gray[0].shape
# Out:
# (512, 512)

# %%
ani_gray[2].shape
# Out:
# (512, 512)

# %%
u1_gray[4].shape
# Out:
# (512, 512)

# %%
len_of_images_gv=len(gv_gray)

# %%
len_of_images_ani=len(ani_gray)

# %%
len_of_images_u1=len(u1_gray)

# %%
image_size_gv=gv_gray[4].shape
image_size_gv
# Out:
# (512, 512)

# %%
image_size_ani=ani_gray[4].shape
image_size_ani
# Out:
# (512, 512)

# %%
image_size_u1=u1_gray[4].shape
image_size_u1
# Out:
# (512, 512)

# %%
flatten_size_gv=image_size_gv[0]*image_size_gv[1]
flatten_size_gv
# Out:
# 262144

# %%
flatten_size_ani=image_size_ani[0]*image_size_ani[1]
flatten_size_ani
# Out:
# 262144

# %%
flatten_size_u1=image_size_u1[0]*image_size_u1[1]
flatten_size_u1
# Out:
# 262144

# %%
for i in range(len_of_images_gv):
    gv_gray[i]=np.ndarray.flatten(gv_gray[i]).reshape(flatten_size_gv,1)

# %%
for i in range(len_of_images_ani):
    ani_gray[i]=np.ndarray.flatten(ani_gray[i]).reshape(flatten_size_ani,1)

# %%
for i in range(len_of_images_u1):
    u1_gray[i]=np.ndarray.flatten(u1_gray[i]).reshape(flatten_size_u1,1)

# %%
gv_gray=np.dstack(gv_gray)

# %%
ani_gray=np.dstack(ani_gray)

# %%
u1_gray=np.dstack(u1_gray)

# %%
gv_gray=np.rollaxis(gv_gray,axis=2,start=0)
gv_gray.shape
# Out:
# (10, 262144, 1)

# %%
ani_gray=np.rollaxis(ani_gray,axis=2,start=0)
ani_gray.shape
# Out:
# (10, 262144, 1)

# %%
u1_gray=np.rollaxis(u1_gray,axis=2,start=0)
u1_gray.shape
# Out:
# (10, 262144, 1)

# %%
gv_gray=gv_gray.reshape(len_of_images_gv,flatten_size_gv)
gv_gray.shape
# Out:
# (10, 262144)

# %%
ani_gray=ani_gray.reshape(len_of_images_ani,flatten_size_ani)
ani_gray.shape
# Out:
# (10, 262144)

# %%
u1_gray=u1_gray.reshape(len_of_images_u1,flatten_size_u1)
u1_gray.shape
# Out:
# (10, 262144)

# %%
gv_data=pd.DataFrame(gv_gray)
gv_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.509434  0.513644  0.498368  0.482461  0.459901  0.437341  0.416286
# 1  0.392532  0.392532  0.392532  0.392532  0.393284  0.395765  0.398245
# 2  0.118993  0.116665  0.118135  0.120464  0.122792  0.126683  0.132504
# 3  0.621448  0.621023  0.602652  0.579151  0.551187  0.528832  0.510923
# 4  0.508306  0.507445  0.508524  0.509602  0.510779  0.512180  0.513582
# 5  0.289984  0.297171  0.288163  0.279154  0.267953  0.251713  0.235472
# 6  0.796375  0.796849  0.795126  0.793561  0.793664  0.793766  0.792602
# 7  0.570060  0.570060  0.570060  0.570060  0.569726  0.568627  0.567528
# 8  0.222096  0.222050  0.222615  0.223465  0.224785  0.226602  0.229598
# 9  0.529639  0.529663  0.528904  0.525347  0.518403  0.508288  0.493807
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.395580  0.382030  0.374684  ...  0.344528  0.344727  0.344772  0.344638
# ...

# %%
ani_data=pd.DataFrame(ani_gray)
ani_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.650444  0.650444  0.650444  0.654120  0.658532  0.662944  0.667356
# 1  0.141817  0.141817  0.141817  0.141866  0.143093  0.144321  0.144994
# 2  0.043853  0.046089  0.043286  0.040483  0.037040  0.032131  0.027221
# 3  0.143399  0.143399  0.143399  0.143399  0.143399  0.143399  0.143399
# 4  0.282192  0.282616  0.281842  0.281068  0.280819  0.280819  0.280790
# 5  0.059817  0.059817  0.059817  0.059817  0.059817  0.059817  0.059817
# 6  0.720541  0.720541  0.720541  0.720541  0.720541  0.720541  0.720541
# 7  0.328684  0.328684  0.328684  0.328684  0.328684  0.328684  0.328684
# 8  0.667642  0.667642  0.667642  0.669775  0.671564  0.671564  0.672141
# 9  0.189736  0.189736  0.189736  0.189736  0.189736  0.189736  0.189736
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.671767  0.676179  0.680591  ...  0.391184  0.523483  0.484168  0.273239
# ...

# %%
u1_data=pd.DataFrame(u1_gray)
u1_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.183985  0.182738  0.184301  0.185864  0.187969  0.191320  0.194671
# 1  0.233751  0.234022  0.233039  0.232021  0.230647  0.229272  0.228607
# 2  0.492104  0.491971  0.492454  0.493044  0.494768  0.496491  0.498214
# 3  0.241810  0.241810  0.241810  0.241810  0.242614  0.244100  0.245586
# 4  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 5  0.934367  0.934367  0.934367  0.935428  0.937412  0.938289  0.938289
# 6  0.464888  0.396565  0.149101  0.122953  0.150418  0.317609  0.516304
# 7  0.479931  0.480176  0.482259  0.482933  0.482933  0.482933  0.482933
# 8  0.973129  0.973129  0.973129  0.973855  0.974803  0.976329  0.977458
# 9  0.665748  0.665748  0.665748  0.665748  0.665748  0.665748  0.665748
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.198782  0.203636  0.208490  ...  0.461480  0.460078  0.458677  0.457275
# ...

# %%
gv_data["label"]="GV Prakesh"
gv_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0
0.328684  0.328684  0.328684  0.328684  0.328684  0.328684
# 3       3  0.143399  0.143399  0.143399  0.143399  0.143399  0.143399
# 4       7  0.479931  0.480176  0.482259  0.482933  0.482933  0.482933
# 5       9  0.665748  0.665748  0.665748  0.665748  0.665748  0.665748
# 6       6  0.464888  0.396565  0.149101  0.122953  0.150418  0.317609
# 7       6  0.720541  0.720541  0.720541  0.720541  0.720541  0.720541
# 8       0  0.650444  0.650444  0.650444  0.654120  0.658532  0.662944
# 9       2  0.492104  0.491971  0.492454  0.493044  0.494768  0.496491
# 10      9  0.529639  0.529663  0.528904  0.525347  0.518403  0.508288
# 11      1  0.141817  0.141817  0.141817  0.141866  0.143093  0.144321
# ...

# %%
celbs_indexed=celbs_indexed.drop(['index'],axis=1)

# %%
celbs_indexed
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.043853  0.046089  0.043286  0.040483  0.037040  0.032131  0.027221
# 1   0.667642  0.667642  0.667642  0.669775  0.671564  0.671564  0.672141
# 2   0.328684  0.328684  0.328684  0.328684  0.328684  0.328684  0.328684
# 3   0.143399  0.143399  0.143399  0.143399  0.143399  0.143399  0.143399
# 4   0.479931  0.480176  0.482259  0.482933  0.482933  0.482933  0.482933
# 5   0.665748  0.665748  0.665748  0.665748  0.665748  0.665748  0.665748
# 6   0.464888  0.396565  0.149101  0.122953  0.150418  0.317609  0.516304
# 7   0.720541  0.720541  0.720541  0.720541  0.720541  0.720541  0.720541
# 8   0.650444  0.650444  0.650444  0.654120  0.658532  0.662944  0.667356
# 9   0.492104  0.491971  0.492454  0.493044  0.494768  0.496491  0.498214
# 10  0.529639  0.529663  0.528904  0.525347  0.518403  0.508288  0.493807
# 11  0.141817  0.141817  0.141817  0.141866  0.143093  0.144321  0.144994
# ...

# %%
celbs_indexed.to_csv("C:/Users/Ganesh Madhav/Desktop/Image Processing.csv")

# %%
x=celbs_indexed.values[:,:-1]

# %%
y=celbs_indexed.values[:,-1]

# %%
x
# Out:
# array([[0.04385263480392156, 0.0460891544117647, 0.04328584558823529,
#         ..., 0.2409723713235294, 0.2395707169117647, 0.2406889767156863],
#        [0.6676422549019607, 0.6676422549019607, 0.6676422549019607, ...,
#         0.15990492929496017, 0.06944102620442708, 0.04342130825865502],
#        [0.3286835294117647, 0.3286835294117647, 0.3286835294117647, ...,
#         0.3081498590686274, 0.30814985906862746, 0.30814985906862746],
#        ...,
#        [0.18398517475464765, 0.18273825752220904, 0.18430117432725196,
#         ..., 0.45166851715686274, 0.450266862745098, 0.45138512254901964],
#        [0.5700598223039216, 0.5700598223039216, 0.5700598223039216, ...,
#         0.6647340658150466, 0.6678808193909889, 0.6653702946801279],
#        [0.5094344679709042, 0.5136437468225815, 0.4983681380866556, ...,
#         0.33354173873265586, 0.3349340762512356, 0.33455040991278256]],
#       dtype=object)

# %%
y
# Out:
# array(['Anni', 'Anni', 'Anni', 'Anni', 'U1', 'U1', 'U1', 'Anni', 'Anni',
#        'U1', 'GV Prakesh', 'Anni', 'Anni', 'GV Prakesh', 'U1',
#        'GV Prakesh', 'GV Prakesh', 'GV Prakesh', 'GV Prakesh',
#        'GV Prakesh', 'U1', 'U1', 'U1', 'U1', 'Anni', 'GV Prakesh', 'Anni',
#        'U1', 'GV Prakesh', 'GV Prakesh'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['U1', 'U1', 'U1', 'U1', 'GV Prakesh', 'U1'], dtype=object)

# %%
for i in (np.random.randint(0,6,35)):
    predicted_images = (np.reshape(x_test[i], (512,512)).astype(np.float64))
    plt.title('predicted label:{0}'. format(y_pred[i]))
    plt.imshow(predicted_images, interpolation='nearest', cmap='gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[0, 1, 2],
#        [0, 0, 3],
#        [0, 0, 0]], dtype=int64)
